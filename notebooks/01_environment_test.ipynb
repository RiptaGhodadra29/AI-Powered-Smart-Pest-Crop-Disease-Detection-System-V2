# %%
import sys
print(sys.executable)
# Out:
# /Users/ripta/Desktop/AI_Powered_Smart_Pest_Crop_Disease_Detection_System/venv/bin/python

# %%
import torch
import torchvision
import albumentations
import cv2
import pandas as pd
import numpy as np

print("All libraries imported successfully")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#       2 import torchvision
#       3 import albumentations
#       4 import cv2
#
# File ~/Desktop/AI_Powered_Smart_Pest_Crop_Disease_Detection_System/venv/lib/python3.13/site-packages/torch/__init__.py:444
#     442     if USE_GLOBAL_DEPS:
#     443         _load_global_deps()
# --> 444     from torch._C import *  # noqa: F403
#     447 class SymInt:
#     448     """
#     449     Like an int (including magic methods), but redirects all operations on the
#     450     wrapped node. This is used in particular to symbolically record operations
#     451     in the symbolic shape workflow.
#     452     """
#
# File <frozen importlib._bootstrap>:463, in _lock_unlock_module(name)
# --> 463 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %%
import sys

print(sys.executable)
# Out:
# /Users/ripta/Desktop/AI_Powered_Smart_Pest_Crop_Disease_Detection_System/venv/bin/python

# %%
import platform

print(platform.python_version())
# Out:
# 3.13.6

# %%
import time

start = time.time()

import torch

print("Loaded in:", time.time() - start)
# Out:
# Loaded in: 0.8819520473480225

# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.6

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
import torch
print(torch.__version__)
# Out:
# 2.12.0

# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# /Users/ripta/Desktop/AI_Powered_Smart_Pest_Crop_Disease_Detection_System/venv/bin/python
# 3.13.6 (v3.13.6:4e665351082, Aug  6 2025, 11:22:35) [Clang 16.0.0 (clang-1600.0.26.6)]
